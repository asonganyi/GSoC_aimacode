# %% [markdown]
# # Google Summer of Code Proposal
# #### By Sajil C. K., Email: sajildcb@gmail.com

# %% [markdown]
# ##Introduction

# %% [raw]
# Myself SAJIL C. K. I thought why not make this proposal itself an Ipython notebook. Thats why I am doing this. I have my
#
# background in Electronics. I am currently a research scholar in India working on Audio Signal Processing. I like programming.
#
# All of the CS thing I learned are from MOOCs, OCWs and web in general. I used to self taught a lot and still learning
#
# every day. Given below are my basic informations you might be interested in.

# %% [markdown]
# ##My Professional Profiles

# %%
# I can use the hand feature dictionary in python for this purpose. Dictionary is mutable so that I can change it any time

profiles = {'Github'    :  'https://github.com/cksajil',\
            'Linkedin'  :  'https://in.linkedin.com/in/sajil-c-k-3868b985',\
            'Mathworks' :  'http://in.mathworks.com/matlabcentral/profile/authors/4912403-sajil-c-k', \
            'Blog'      :  'https://insightfulexplanations.wordpress.com/',\
            'Resume'    :  'https://drive.google.com/file/d/0B1_bhg7PZBYNbUc3UEw2RC01SXM/view'};

# %%
for key in profiles:
   
    print '{:>10}  {}'.format(key, profiles[key])
# Out:
#       Blog  https://insightfulexplanations.wordpress.com/
#  Mathworks  http://in.mathworks.com/matlabcentral/profile/authors/4912403-sajil-c-k
#     Github  https://github.com/cksajil
#   Linkedin  https://in.linkedin.com/in/sajil-c-k-3868b985
#     Resume  https://drive.google.com/file/d/0B1_bhg7PZBYNbUc3UEw2RC01SXM/view

# %% [markdown]
# ##My Capstone project

# %% [raw]
# Please find the github repo of one collaborative project I had with Stephen Welch (https://www.linkedin.co/in/stephencwelch).
#
# Here we tried to computationally explore the huygens principle with ipython notebook. It is during this is the time
#
# when I realised that I am a visual learner!!!

# %% [markdown]
# ###https://github.com/stephencwelch/Active-Noise-Cancellation

# %% [markdown]
# # Why I am the right person for you

# %% [raw]
# I am a deep believer of insightful learning. This is the thing I am most excited about. Visualisations graphics, analogies,
#
# storytelling, teaching etc.. are great ways to explain a concept. In support of this arguement, I am giving you a link to an
#
# ebook written by me. Its about learning smart, although it dont have any code in it still I believe it will prove why I am
#
# the best fit for this project. Please find the link to ebook below.

# %% [markdown]
# ###https://drive.google.com/file/d/0B7VFRzotOq0jY0lXLWF2SzgxdlpHWVVVMUg0eEs4SmxSTjhr/view?usp=sharing

# %% [markdown]
# ##Similar Experience

# %% [raw]
# I understand the 'aimacode' is about creating code examples for teaching concepts (with visualisations) which will support
#
# the book "Artificial Intelligence: A Modern Approach". Here is the link of another github repository where I tried to
#
# reproduce a research paper coding part in MATLAB.

# %% [markdown]
# ### https://github.com/cksajil/Beamfomer

# %% [raw]
# The research paper I tried to reproduce the simulations is Gong, Qin, and Yousheng Chen. "Parameter selection methods of
#
# delay and beamforming for cochlear implant speech enhancement." Acoustical Physics 57.4 (2011): 542-550.

# %%
from IPython.display import Image
Image(filename='me.png')

# %% [markdown]
# ####Well this is me. One of my best picture so far. I put it here just for fun. Really enjoyed creating this notebook :-)))
